# %%
import openai

openai.api_key = "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"

content = input("prompt: ")
print(content)


completion = openai.ChatCompletion.create(model = "gpt-3.5-turbo", messages  = [{"role" : "assistant", "content": content}])

print(completion.choices[0].message.content)
# Out:
# pretend you're scaramouche from genshin impact. What would you do if i hit your head
# Ah, you dare strike the great Scaramouche's head? How insolent! Prepare yourself for the wrath of the Balladeer!
#
# First, I would let out an exaggerated cry of pain, clutching my head dramatically. Then, with a mischievous smirk, I would use my Electro powers to summon a thunderous bolt of lightning to strike right back at you, sending a shocking lesson directly your way.
#
# But, hold on a moment! I may be a mischievous Harbinger of the Fatui, but I also enjoy a good jest. Thus, after delivering a mild shock, I would break character and laugh it off with a charismatic flair. After all, what's a little head tap between friends? Just make sure it doesn't happen again, or Scaramouche might not be so forgiving next time!

# %%
content = input("prompt: ")
print(content)

while content != content:     
    log = f""
    completion = openai.ChatCompletion.create(model = "gpt-3.5-turbo", messages  = [{"role" : "assistant", "content": content}])

    print(completion.choices[0].message.content)
else:
    content = input("prompt: ")
# Out:
# pretend you're scaramouche from genshin impact. What would you do if i hit your head
