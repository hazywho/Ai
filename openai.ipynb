# %%
import openai

openai.api_key = "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"

content = input("prompt: ")
print(content)


completion = openai.ChatCompletion.create(model = "gpt-3.5-turbo", messages  = [{"role" : "assistant", "content": content}])

print(completion.choices[0].message.content)
# Out:
# pretend you're scaramouche from genshin impact. What would you do if i hit your head
# Ohoho! You dare strike the head of Scaramouche, the sixth of the Fatui Harbingers? Impudent fool! Prepare to face the consequences of your foolish actions! I shall summon my thunderous powers and bring forth an electrical storm to strike you down! You shall be left quivering in fear before the might of the Fatui! Hahaha!

# %%
pretend you're scaramouche from genshin impact. What would you do if i hit your head
# Out:
# pretend you're scaramouche from genshin impact. What would you do if i hit your head
