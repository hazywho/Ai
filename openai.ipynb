# %%
import openai

openai.api_key = "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"

content = input("prompt: ")
print(content)

while content != content:     
    log = f""
    completion = openai.ChatCompletion.create(model = "gpt-3.5-turbo", messages  = [{"role" : "assistant", "content": content}])

    print(completion.choices[0].message.content)
else:
    content = input("prompt: ")
# Out:
# pretend you're scaramouche from genshin impact. What would you do if i hit your head
# Oh, you dare to hit the great Scaramouche's head? Well then, I suppose I would have to retaliate. You may think you're tough, but I assure you, you wouldn't want to feel the full force of my power. So I suggest you think twice before trying to mess with me again.
